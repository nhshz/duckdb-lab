# %%
import pandas as pd
df = pd.read_parquet('../data/review_data')
df
# Out:
#         marketplace customer_id       review_id  product_id product_parent  \
# 0                US    42778291   R36DE7C83302X  B0034GY4L8      652273641
# 1                US    51900780  R264BJL39GBDF8  B00FJTYDKK      255137298
# 2                US    50549774   RZ43SQJAS1IV6  B006MW3V6U      682981764
# 3                US    13886817  R2WP035BBNAQBZ  B00I3MNJZ0       47146773
# 4                US    51177115  R2HRSJ5OWRLKKF  B006LZSF8M      175214460
# ...             ...         ...             ...         ...            ...
# 5173738          UK     9578477  R2FODDGJM3ZK4P  B00IKV6NJI      138697351
# 5173739          UK    27482601  R1617RH3DSKADB  B00IHRZOC2      126004443
# 5173740          UK    33629432   RLH0N6NEMKEVT  B00G15K7GA      534568128
# 5173741          UK    39810136  R2UXKHMAEQOTZQ  B00EUSY6K8      502503276
# 5173742          UK    48065133   RKM7GC2EM8K4Z  B00OCG4D1U      664245088
#
# ...
